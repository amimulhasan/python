# %% [markdown]
# <a href="https://colab.research.google.com/github/amimulhasan/python/blob/main/algorithom_compaire.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,0.8,0.8])
algo = ['LR','RF', 'DT', 'XGB','KNN']
acc = [0.68,0.93,0.93,0.93,0.82]
ax.bar(algo,acc)
ax.set_xlabel('Models')
ax.set_ylabel('Accuracy Score')
ax.set_title('Algorithm Comparison')
plt.show()
