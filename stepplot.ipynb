# %% [markdown]
# # step plot

# %%
import matplotlib.pyplot as plt
x=[3,2,3,4,5]
y=[3,2,4,6,7]
plt.step(x,y,marker="o",color="r",mfc="g",label="python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid()
plt.legend()
plt.show()
