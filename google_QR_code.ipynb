# %% [markdown]
# <a href="https://colab.research.google.com/github/amimulhasan/python/blob/main/google_QR_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install qrcode[pil]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 1.5 MB/s eta 0:00:00
# ...

# %%
import qrcode

data = "https://www.google.com"

qr = qrcode.make(data)

qr.save("basic_qr.png")

print("QR Code generated successfully!")
# Out:
# QR Code generated successfully!
