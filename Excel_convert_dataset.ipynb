# %% [markdown]
# <a href="https://colab.research.google.com/github/amimulhasan/python/blob/main/Excel_convert_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Data for the table
data = {
    'Class': [0, 1, 2, 3],
    'Precision': [1.0000, 1.0000, 1.0000, 1.0000],
    'Recall': [1.0000, 1.0000, 1.0000, 1.0000],
    'F1-Score': [1.0000, 1.0000, 1.0000, 1.0000],
    'Support': [600, 98, 600, 600]
}

# Creating a DataFrame
df = pd.DataFrame(data)

# Saving to an Excel file
file_path = '/mnt/data/classification_metrics.xlsx'
df.to_excel(file_path, index=False)

file_path
